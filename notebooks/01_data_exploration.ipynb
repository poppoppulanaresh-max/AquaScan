# %% [markdown]
# # 01. Data Exploration and Analysis
# This notebook contains the exploratory data analysis for microplastic image datasets. It analyzes image dimensions, label distributions, class frequencies, and boundary box sizes.
