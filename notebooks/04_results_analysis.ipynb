# %% [markdown]
# # 04. Results & Classifier Performance Analysis
# This notebook trains and evaluates the XGBoost classifier that categorizes pollution severity based on particle counts, class ratios, and density maps.
