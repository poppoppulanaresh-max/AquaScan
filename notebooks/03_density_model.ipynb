# %% [markdown]
# # 03. CSRNet Density Model Architecture & Training
# This notebook covers the CSRNet density estimation model. It generates ground truth density maps using geometry-adaptive kernels and runs model training.
